# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Libraries

# %%
import bibtexparser
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parse .bib File

# %%
with open('Transportation_Research_Part_C.bib') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# %% [markdown]
# ## Create Pandas Dataframe

# %%
P = pd.DataFrame(bib_database.entries)
P
# Out:
#                                               abstract  \
# 0    Multi-vehicle routing problem with soft time w...
# 1    The present work investigates the use of smart...
# 2    This paper employs deep learning in detecting ...
# 3    A large portion of passenger requests is repor...
# 4    The accurate short-term passenger flow predict...
# ..                                                 ...
# 495  This paper addresses departure time and route ...
# 496  The increasing availability of opportunistic a...
# 497  As employers, suppliers, and transport provide...
# 498  This paper proposes a framework for evaluating...
# 499  This article proposes an efficient multiple mo...
#
#                                               keywords  \
# 0    Reinforcement learning, Vehicle routing proble...
# 1    Driver’s behavior, Critical driving patterns, ...
# 2    Traffic accident detection, Tweet, Social medi...
# 3    Mean field multi-agent reinforcement learning,...
# 4    Deep learning, Sequence to sequence, Attention...
# ..                                                 ...
# 495                                                NaN
# 496  Trip travel time distribution, Markov chain, C...
# 497  GPS data, Activity-travel patterns, Business t...
# 498  Dynamic journey travel time distribution, Rela...
# 499  Traffic estimation, Traffic incident detection...
#
#                                                 author  \
# 0    Ke Zhang and Fang He and Zhengchao Zhang and X...
# 1    Eleni I. Vlahogianni and Emmanouil N. Barmpoun...
# 2    Zhenhua Zhang and Qing He and Jing Gao and Min...
# 3                              Zhenyu Shou and Xuan Di
# 4               Siyu Hao and Der-Horng Lee and De Zhao
# ..                                                 ...
# 495                 Hani S. Mahmassani and Yu-Hsin Liu
# 496  Zhenliang Ma and Haris N. Koutsopoulos and Lui...
# 497  Feng liu and Ziyou Gao and Davy Janssens and B...
# 498  Agachai Sumalee and Tianlu Pan and Renxin Zhon...
# 499         Ren Wang and Shimao Fan and Daniel B. Work
#
#                                                    url  \
# 0    https://www.sciencedirect.com/science/article/...
# 1    https://www.sciencedirect.com/science/article/...
# 2    https://www.sciencedirect.com/science/article/...
# 3    https://www.sciencedirect.com/science/article/...
# 4    https://www.sciencedirect.com/science/article/...
# ..                                                 ...
# 495  https://www.sciencedirect.com/science/article/...
# 496  https://www.sciencedirect.com/science/article/...
# 497  https://www.sciencedirect.com/science/article/...
# 498  https://www.sciencedirect.com/science/article/...
# 499  https://www.sciencedirect.com/science/article/...
#
#                                                doi       issn  year    pages  \
# 0        https://doi.org/10.1016/j.trc.2020.102861  0968-090X  2020   102861
# 1        https://doi.org/10.1016/j.trc.2017.03.014  0968-090X  2017  196-206
# 2        https://doi.org/10.1016/j.trc.2017.11.027  0968-090X  2018  580-596
# 3        https://doi.org/10.1016/j.trc.2020.102738  0968-090X  2020   102738
# 4        https://doi.org/10.1016/j.trc.2019.08.005  0968-090X  2019  287-300
# ..                                             ...        ...   ...      ...
# 495  https://doi.org/10.1016/S0968-090X(99)00014-5  0968-090X  1999   91-107
# 496      https://doi.org/10.1016/j.trc.2016.11.008  0968-090X  2017     1-21
# 497      https://doi.org/10.1016/j.trc.2021.103136  0968-090X  2021   103136
# 498      https://doi.org/10.1016/j.trc.2012.11.003  0968-090X  2013  263-285
# 499      https://doi.org/10.1016/j.trc.2016.08.003  0968-090X  2016  521-537
#
#     volume                                            journal  \
# 0      121  Transportation Research Part C: Emerging Techn...
# 1       79  Transportation Research Part C: Emerging Techn...
# 2       86  Transportation Research Part C: Emerging Techn...
# 3      119  Transportation Research Part C: Emerging Techn...
# 4      107  Transportation Research Part C: Emerging Techn...
# ..     ...                                                ...
# 495      7  Transportation Research Part C: Emerging Techn...
# 496     74  Transportation Research Part C: Emerging Techn...
# 497    128  Transportation Research Part C: Emerging Techn...
# 498     35  Transportation Research Part C: Emerging Techn...
# 499     71  Transportation Research Part C: Emerging Techn...
#
#                                                  title ENTRYTYPE  \
# 0    Multi-vehicle routing problems with soft time ...   article
# 1    Driving analytics using smartphones: Algorithm...   article
# 2    A deep learning approach for detecting traffic...   article
# 3    Reward design for driver repositioning using m...   article
# 4    Sequence to sequence learning with attention m...   article
# ..                                                 ...       ...
# 495  Dynamics of commuting decision behaviour under...   article
# 496  Estimation of trip travel time distribution us...   article
# 497  Identifying business activity-travel patterns ...   article
# 498  Dynamic stochastic journey time estimation and...   article
# 499  Efficient multiple model particle filtering fo...   article
#
#                      ID note number
# 0       ZHANG2020102861  NaN    NaN
# 1    VLAHOGIANNI2017196  NaN    NaN
# 2          ZHANG2018580  NaN    NaN
# 3        SHOU2020102738  NaN    NaN
# 4            HAO2019287  NaN    NaN
# ..                  ...  ...    ...
# 495    MAHMASSANI199991  NaN      2
# 496             MA20171  NaN    NaN
# 497       LIU2021103136  NaN    NaN
# 498      SUMALEE2013263  NaN    NaN
# 499         WANG2016521  NaN    NaN
#
# [500 rows x 15 columns]

# %% [markdown]
# # Fields in .bib File

# %%
for row in P:
    print (row)
# Out:
# abstract
# keywords
# author
# url
# doi
# issn
# year
# pages
# volume
# journal
# title
# ENTRYTYPE
# ID
# note
# number

# %% [markdown]
# # Keywords
# ## Sort Keywords by Frequency

# %%
P['keywords'] = P['keywords'].fillna('None')
A = [ x.split(', ') for x in P['keywords'].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# {'Machine learning': 44,
#  'Deep learning': 31,
#  'None': 18,
#  'Big data': 15,
#  'Data mining': 14,
#  'Clustering': 13,
#  'Traffic flow': 11,
#  'Reinforcement learning': 10,
#  'Prediction': 10,
#  'Traffic forecasting': 9,
#  'Autonomous vehicles': 9,
#  'Social media': 8,
#  'Car-following': 8,
#  'Air traffic management': 7,
#  'Classification': 7,
#  'GPS': 7,
#  'Intelligent transportation systems': 7,
#  'Traffic prediction': 7,
#  'Neural network': 7,
#  'Calibration': 7,
#  'Driving behavior': 6,
#  'Feature selection': 6,
#  'Road safety': 6,
#  'Travel behavior': 6,
#  'Random forest': 6,
#  'Safety': 6,
#  'Agent-based model': 5,
#  'Survey': 5,
#  'Anomaly detection': 5,
#  'Artificial neural network': 5,
#  'Route choice': 5,
#  'Traffic state estimation': 5,
#  'Cluster analysis': 5,
#  'Computer vision': 5,
#  'Public transport': 5,
#  'Missing data': 5,
#  'Agent-based modeling': 5,
#  'Travel time prediction': 5,
#  'Intelligent transportation system': 5,
#  'Driver behaviour': 5,
#  'Neural networks': 5,
#  'Dynamic traffic assignment': 5,
#  'Smartphones': 4,
#  'GPS data': 4,
#  'Short-term prediction': 4,
#  'Connected vehicles': 4,
#  'Recurrent neural network': 4,
#  'LSTM': 4,
#  'Traffic flow prediction': 4,
#  'Vehicle classification': 4,
#  'Recurrent neural networks': 4,
#  'Pattern recognition': 4,
#  'Dynamic programming': 4,
#  'Optimization': 4,
#  'Kalman filter': 4,
#  'Bayesian networks': 4,
#  'Uncertainty': 4,
#  'Congestion': 4,
#  'Driving simulator': 4,
#  'Travel survey': 4,
#  'Human mobility': 4,
#  'Genetic algorithms': 4,
#  'Incident detection': 4,
#  'Smart card data': 4,
#  'Attention': 3,
#  'Deep reinforcement learning': 3,
#  'Eco-driving': 3,
#  'Lane-changing': 3,
#  'Real-time crash prediction': 3,
#  'Graph convolution': 3,
#  'Convolutional neural network': 3,
#  'Artificial neural networks': 3,
#  'Fuzzy logic': 3,
#  'BADA': 3,
#  'Forecasting': 3,
#  'Travel time': 3,
#  'Supervised learning': 3,
#  'Data-driven': 3,
#  'Trajectory prediction': 3,
#  'Air traffic control': 3,
#  'Travel demand': 3,
#  'Deep neural network': 3,
#  'Short-term forecasting': 3,
#  'Ensemble learning': 3,
#  'Air Traffic Management': 3,
#  'Artificial intelligence': 3,
#  'Traffic volume estimation': 3,
#  'Feature extraction': 3,
#  'License plate recognition data': 3,
#  'Air traffic flow management': 3,
#  'Sensor fusion': 3,
#  'Ride-hailing': 3,
#  'Random forests': 3,
#  'Support vector machine': 3,
#  'Text mining': 3,
#  'Approximate dynamic programming': 3,
#  'Particle filter': 3,
#  'Topic modeling': 3,
#  'Activity-based modeling': 3,
#  'Multi-source data': 3,
#  'Probe data': 3,
#  'Bayesian network': 3,
#  'Population synthesis': 3,
#  'Traffic monitoring': 3,
#  'Urban expressway': 3,
#  'Data fusion': 3,
#  'Nested logit model': 3,
#  'Smartphone': 3,
#  'Probe vehicle': 3,
#  'Floating car data': 3,
#  'GARCH': 3,
#  'Intelligent Transportation Systems': 3,
#  'Privacy': 3,
#  'ITS': 3,
#  'Markov decision process': 3,
#  'Natural language processing': 3,
#  'Parking': 3,
#  'Intelligent vehicles': 3,
#  'Ride-sourcing': 3,
#  'Bayesian inference': 3,
#  'Condition-based maintenance': 3,
#  'Travel pattern': 3,
#  'Dynamic ridesharing': 3,
#  'Fuel efficiency': 3,
#  'Car-following model': 3,
#  'Autonomous vehicle': 3,
#  'Vehicle routing problem': 2,
#  'Attention mechanism': 2,
#  'Multi-agent': 2,
#  'Driver’s behavior': 2,
#  'Tweet': 2,
#  'Bayesian optimization': 2,
#  'Passenger flow': 2,
#  'Activity-based model': 2,
#  'Automated vehicle': 2,
#  'Vehicle trajectory': 2,
#  'Long short-term memory': 2,
#  'Decision support system': 2,
#  'Last-mile delivery': 2,
#  'Travel demand forecasting': 2,
#  'Bike sharing': 2,
#  'Deep Learning': 2,
#  'Short-term demand forecasting': 2,
#  'Long short-term memory (LSTM)': 2,
#  'Airport operations': 2,
#  'Flight safety': 2,
#  'Survival analysis': 2,
#  'Model interpretability': 2,
#  'Car-following models': 2,
#  'Aircraft trajectory prediction': 2,
#  'Accessibility': 2,
#  'Graph convolutional network': 2,
#  'Extreme gradient boosting': 2,
#  'Time series': 2,
#  'Short-term traffic prediction': 2,
#  'Machine learning methods': 2,
#  'Trajectory data analytics': 2,
#  'Air traffic flows': 2,
#  'Multi-airport systems': 2,
#  'Revenue management': 2,
#  'Ridesharing': 2,
#  'Driver state monitoring': 2,
#  'Anomalous driving detection': 2,
#  'Railway infrastructure': 2,
#  'Train delays': 2,
#  'Semi-supervised learning': 2,
#  'Point-mass model': 2,
#  'Flows': 2,
#  'Activity-based models': 2,
#  'Entropy': 2,
#  'Air transportation': 2,
#  'Choice analysis': 2,
#  'Interpretability': 2,
#  'Urban rail transit': 2,
#  'Rail defect prediction': 2,
#  'Information fusion': 2,
#  'Traffic speed prediction': 2,
#  'Regression': 2,
#  'Adaptive traffic signal control': 2,
#  'Risk': 2,
#  'Travel demand modeling': 2,
#  'Bus bunching': 2,
#  'Fuzzy inference system': 2,
#  'Network-wide traffic prediction': 2,
#  'ARIMA': 2,
#  'RNN': 2,
#  'Trajectories': 2,
#  'Demand prediction': 2,
#  'Mobile phone data': 2,
#  'Urban mobility': 2,
#  'Microsimulation': 2,
#  'Mutual information': 2,
#  'Mobile traffic sensors': 2,
#  'Hidden Markov model': 2,
#  'Gaussian process': 2,
#  'ADS-B': 2,
#  'Adaptive control': 2,
#  'Community detection': 2,
#  'Transportation': 2,
#  'Random forest model': 2,
#  'Tour generation': 2,
#  'OD demand prediction': 2,
#  'Vehicle detection': 2,
#  'Demand forecasting': 2,
#  'Speed estimation': 2,
#  'Data-driven approaches': 2,
#  'Human-automation interaction': 2,
#  'Data imputation': 2,
#  'Machine vision': 2,
#  'Markov decision processes': 2,
#  'ADAS': 2,
#  'Trip purpose': 2,
#  'Traffic management': 2,
#  'Support vector machines': 2,
#  'Bayesian Networks': 2,
#  'Dynamic Traffic Assignment': 2,
#  'Generative modeling': 2,
#  'Variational Autoencoder': 2,
#  'Transportation modeling': 2,
#  'Trip purpose prediction': 2,
#  'Google Places': 2,
#  'Automation': 2,
#  'Mixed traffic flow': 2,
#  'Smartcard data': 2,
#  'Connected and autonomous vehicles': 2,
#  'Prediction interval': 2,
#  'Case-based reasoning': 2,
#  'Variable importance': 2,
#  'Travel mode detection': 2,
#  'Data driven': 2,
#  'Principal component analysis': 2,
#  'PCA': 2,
#  'Mobility': 2,
#  'Trajectory data': 2,
#  'Transit smart card': 2,
#  'Cooperation': 2,
#  'Game theory': 2,
#  'Data analytics': 2,
#  'Route guidance': 2,
#  'Bayesian Network': 2,
#  'Special events': 2,
#  'Response time': 2,
#  'Traffic': 2,
#  'Simulation-based optimization': 2,
#  'Systematic review': 2,
#  'Mode choice': 2,
#  'Mode detection': 2,
#  'Behaviour': 2,
#  'Simulator': 2,
#  'Experiment': 2,
#  'Automated vehicles': 2,
#  'Traffic dynamics': 2,
#  'Missing values': 2,
#  'Travel demand estimation': 2,
#  'AFC data': 2,
#  'Locally weighted regression': 2,
#  'Spatiotemporal traffic data': 2,
#  'Missing data imputation': 2,
#  'Copula': 2,
#  'Shared mobility': 2,
#  'Traffic congestion prediction': 2,
#  'Telematics': 2,
#  'Personalization': 2,
#  'Decision Support Tool': 2,
#  'Open data': 2,
#  'Multi-agent simulation': 2,
#  'Naturalistic driving study': 2,
#  'Transportation mode detection': 2,
#  'Convex optimization': 2,
#  'Stochastic gradient descent': 2,
#  'Fleet management': 2,
#  'Mobility-on-demand': 2,
#  'Freight transportation': 2,
#  'On-demand mobility': 2,
#  'Green driving': 2,
#  'Model predictive control': 2,
#  'Real-time system': 2,
#  'Cell transmission model': 2,
#  'Macroscopic fundamental diagram (MFD)': 2,
#  'Perimeter control': 2,
#  'MPC': 2,
#  'Simulation': 2,
#  'MFD': 2,
#  'Connected vehicle': 2,
#  'Public transportation': 2,
#  'Mixed traffic': 2,
#  'Activity-travel patterns': 2,
#  'Vehicle routing': 2,
#  'Electric vehicles': 2,
#  'Traffic estimation': 2,
#  'Heuristics': 2,
#  'Computational efficiency': 1,
#  'Critical driving patterns': 1,
#  'Rough set theory': 1,
#  'Traffic accident detection': 1,
#  'Association rules': 1,
#  'Mean field multi-agent reinforcement learning': 1,
#  'Reward design': 1,
#  'Sequence to sequence': 1,
#  'metro': 1,
#  'Travel demand model': 1,
#  'Population modelling': 1,
#  'Model validation': 1,
#  'Decision making': 1,
#  'Reward function': 1,
#  'Freight rail': 1,
#  'Data driven estimation': 1,
#  'Deep belief network': 1,
#  'Crew scheduling constraints': 1,
#  'Learning constraints': 1,
#  'Truck-drone routing': 1,
#  'Integrated optimization approach': 1,
#  'Clustering delivery locations': 1,
#  'Minimize total cost': 1,
#  'Minimize delivery completion time': 1,
#  'Transportation systems': 1,
#  'Passenger flow prediction': 1,
#  'Deep learning architecture': 1,
#  'Domain knowledge': 1,
#  'Connected and automated vehicles': 1,
#  'Hybrid reinforcement learning': 1,
#  'Policy gradient': 1,
#  'Deep Q-learning': 1,
#  'Fusion framework': 1,
#  'SMOTE': 1,
#  'Spatial correlation': 1,
#  'Multiple steps ahead forecasting': 1,
#  'Sequence to sequence architecture': 1,
#  'Sharing mobility': 1,
#  'Station-free bike sharing': 1,
#  'Long short-term memory networks': 1,
#  'Traffic Flows': 1,
#  'Trend filtering': 1,
#  'Sparse linear models': 1,
#  'On-demand ride services': 1,
#  'Deep learning (DL)': 1,
#  'Fusion convolutional long short-term memory network (FCL-Net)': 1,
#  'Convolutional neural network (CNN)': 1,
#  'Transportation mode Inference': 1,
#  'Metroplex operations': 1,
#  'Air traffic surveillance data': 1,
#  'Scheduled commercial flight': 1,
#  'Multivariate Gaussian': 1,
#  'Unsupervised learning': 1,
#  'Performance evaluation': 1,
#  'Multistep prediction': 1,
#  'Sequence-to-sequence model': 1,
#  'Train arrival delays': 1,
#  'Support vector regression': 1,
#  'Infrastructure': 1,
#  'Statistics': 1,
#  'Autoencoder': 1,
#  'BRT': 1,
#  'Virtual reality': 1,
#  'Pedestrian crossing behaviour': 1,
#  'Pedestrian wait time': 1,
#  'Pre-emptive lane-changing risk prediction': 1,
#  'Resampling method': 1,
#  'Urban vehicle trajectories': 1,
#  'Trajectory data analysis': 1,
#  'Trajectory data generation': 1,
#  'Generative model': 1,
#  'Generative adversarial imitation learning': 1,
#  'Safety critical events': 1,
#  'Naturalistic data': 1,
#  'Energy rate': 1,
#  'Mass estimation': 1,
#  'Thrust law': 1,
#  'Asset management': 1,
#  'Pedestrian infrastructure': 1,
#  'ADA': 1,
#  'LIDAR': 1,
#  'Airspace operation complexity': 1,
#  'Complexity evaluation': 1,
#  'Small samples': 1,
#  'Knowledge transfer': 1,
#  'Evaluator integration': 1,
#  'Economic risk': 1,
#  'Economic severity': 1,
#  'ATFM regulations': 1,
#  'Cost of delay': 1,
#  'Strategic flight planning': 1,
#  'Airway congestion': 1,
#  'Long short-term memory network': 1,
#  'Kernel method': 1,
#  'Public event prediction': 1,
#  'Traffic shock wave': 1,
#  'Long-short term memory': 1,
#  'Transfer learning': 1,
#  'Model transferability': 1,
#  'Stacked LSTM network': 1,
#  'Terminal area': 1,
#  'High-speed rail': 1,
#  'Train choice': 1,
#  'Online booking data': 1,
#  'Tensor factorization': 1,
#  'Latent class analysis': 1,
#  'Predictive maintenance': 1,
#  'Decision support': 1,
#  'Switches and crossings': 1,
#  'LIME': 1,
#  'Simultaneous modeling': 1,
#  'Long Short-Term Memory': 1,
#  'Driving style classification': 1,
#  'Unsupervised machine learning': 1,
#  'Location-based services': 1,
#  'Basic safety message': 1,
#  'Graphical model': 1,
#  'Max-margin learning': 1,
#  'App-user interaction data': 1,
#  'Personalized behavior model': 1,
#  'Parking prediction': 1,
#  'Multi-source traffic data': 1,
#  'Weather conditions': 1,
#  'Parking transactions': 1,
#  'Traffic speed of lanes': 1,
#  'Long short-term memory neural network': 1,
#  'Gated recurrent unit neural network': 1,
#  'Pavement roughness': 1,
#  'Large-scale measurement': 1,
#  'Power spectral density': 1,
#  'Full-car simulation': 1,
#  'On-demand ride hailing': 1,
#  'Taxi market': 1,
#  'Deep neural network (DNN)': 1,
#  'Active demand management (ADM)': 1,
#  'Activity scheduling': 1,
#  'Population cohorts': 1,
#  'Preferences': 1,
#  'Shared automated vehicles': 1,
#  'Private automated vehicles': 1,
#  'Population synthesizing': 1,
#  'Generative modelling': 1,
#  'Variational Bayesian inference': 1,
#  'Travel behaviour modelling': 1,
#  'Aircraft boarding': 1,
#  'Progress Prediction': 1,
#  'Attention model': 1,
#  'Deep neural network visualization': 1,
#  'Train capacity': 1,
#  'Operation safety': 1,
#  'Coordinated passenger inflow control': 1,
#  'Convolutional neural networks': 1,
#  'Congestion recognition': 1,
#  'Traffic state classification': 1,
#  'Graph convolutional neural network': 1,
#  '4D trajectory prediction': 1,
#  'Multi-cells neural network': 1,
#  'Gradient boosting regression tree': 1,
#  'Foot-by-foot track geometry': 1,
#  'Imbalanced dataset': 1,
#  'Partial dependence analysis': 1,
#  'Conflict': 1,
#  'Vertical profile': 1,
#  'Artificial Neural Networks': 1,
#  'Condition based maintenance': 1,
#  'Multiple wayside detectors': 1,
#  'Predictive modeling': 1,
#  'Rail network velocity': 1,
#  'Traffic flow state classification': 1,
#  'Smartphone senor data': 1,
#  'Deep Belief Network': 1,
#  'Car collision': 1,
#  'Crashworthiness': 1,
#  'Structural forensic analysis': 1,
#  'Inverse solution': 1,
#  'Traffic accident': 1,
#  'Urban network': 1,
#  'Bidirectional long short-term memory neural network': 1,
#  'Mass': 1,
#  'Speed': 1,
#  'Machine Learning': 1,
#  'Gradient Boosting Machines': 1,
#  'Stop delivery time': 1,
#  'Hazard duration': 1,
#  'Feature importance': 1,
#  'Taxi time': 1,
#  'Multi-agent reinforcement learning': 1,
#  'Regional green wave control': 1,
#  'CVIS': 1,
#  'Sequence to sequence (seq2seq)': 1,
#  'Reaction delay': 1,
#  'Discrete Choice': 1,
#  'Random Forest': 1,
#  'Landing performance': 1,
#  'Track quality index': 1,
#  'Principal components': 1,
#  'Railway engineering': 1,
#  'Cycle-level': 1,
#  'Turning movement counts': 1,
#  'Residual logit': 1,
#  'Data-driven discrete choice modelling': 1,
#  'Non-linear utility': 1,
#  'Multi-layered neural networks': 1,
#  'Vehicle probe data': 1,
#  'Artificial intelligence (AI)': 1,
#  'Autonomous vehicle (AV) control': 1,
#  'Mixed autonomy': 1,
#  'Transport network flow estimation': 1,
#  'Gradient boosting': 1,
#  'Cellphone location data': 1,
#  'Proactive relocation': 1,
#  'Vehicle dispatching': 1,
#  'Optimal matching': 1,
#  'Stable matching': 1,
#  'Sequence classification': 1,
#  'Ridesourcing': 1,
#  'Deadheading': 1,
#  'Graph embedding': 1,
#  'Generative adversarial network': 1,
#  'Deepwalk': 1,
#  'Transit delays': 1,
#  'Crowdsourced data': 1,
#  'Delay pattern identification': 1,
#  'Bayesian network learning': 1,
#  'Network dependency metrics': 1,
#  'Ground delay program': 1,
#  'Mobility data': 1,
#  'Citywide people mass movement simulation': 1,
#  'Dynamic holding': 1,
#  'Multi-agent system': 1,
#  'Policy proximal optimization': 1,
#  'Driving style evaluation': 1,
#  'Ensemble machine learning algorithms': 1,
#  'Postprocess residuals': 1,
#  'MSVR': 1,
#  'GPS\xa0+\xa0GIS fusion': 1,
#  'Stop detection': 1,
#  'Smartphone based travel surveys': 1,
#  'ANN': 1,
#  'CNN': 1,
#  'Point based classification': 1,
#  'Time-varying preferences': 1,
#  'Smart transportation demand management': 1,
#  'Personalized behavior modeling': 1,
#  'Vehicle simulation': 1,
#  'Energy consumption estimation': 1,
#  'Numerosity reduction': 1,
#  'Random sampling': 1,
#  'Autonomie': 1,
#  'CAFE': 1,
#  'Deep multi-task learning': 1,
#  'Multi-graph convolutional network': 1,
#  'Knock-on delay': 1,
#  'Root cause discovering': 1,
#  'Delay propagation': 1,
#  'Railway disruption': 1,
#  'Aircraft performances': 1,
#  'Trajectory calculation': 1,
#  'Traffic behavior': 1,
#  'AVI data': 1,
#  'Driver trust measurement': 1,
#  'Automated vehicle technology': 1,
#  'Hand position transition probability': 1,
#  'Objective measure': 1,
#  'Bias-correction': 1,
#  'LASSO': 1,
#  'Bicycling ridership': 1,
#  'Exposure': 1,
#  'Strava': 1,
#  'Origin destination matrix': 1,
#  'Transport mode': 1,
#  'Travel flows': 1,
#  'Games on social networks': 1,
#  'Machine-learning': 1,
#  'Network interventions': 1,
#  'Climate change policy': 1,
#  'Mode shift': 1,
#  'Social welfare maximization': 1,
#  'Peer-pressure': 1,
#  'SVM': 1,
#  'Probabilistic fusion': 1,
#  'Matching-scores': 1,
#  'Bimodal Kernel': 1,
#  'Infrared images': 1,
#  'Obstacle recognition': 1,
#  'Travel time distribution': 1,
#  'Generative adversarial networks': 1,
#  'Wasserstein distance': 1,
#  'Spatiotemporal correlation': 1,
#  'Detrending': 1,
#  'Multi-scale traffic prediction': 1,
#  'Self-adaptive sampling': 1,
#  'Vehicle state estimation': 1,
#  'Stop and go traffic': 1,
#  'Over-sampling': 1,
#  'Undersampling': 1,
#  'ITS control': 1,
#  'Deep convolutional generative adversarial network': 1,
#  'Traffic flow forecasting': 1,
#  'Tourists': 1,
#  'Destination choice': 1,
#  'Location based social media': 1,
#  'Florida': 1,
#  'GIS': 1,
#  'Travel time forecasting': 1,
#  'Non-parametric regression': 1,
#  'Historical database': 1,
#  'Parameter adjustment': 1,
#  'Real-time queue length estimation': 1,
#  'Lane-based estimation': 1,
#  'Cumulative arrival–departure curve': 1,
#  'Boundary constrained car-following model': 1,
#  'Cyber-physical system': 1,
#  'Weigh-in-motion': 1,
#  'Transportation infrastructure management': 1,
#  'Structural health monitoring': 1,
#  'Vehicle tracking': 1,
#  'License-plate recognition': 1,
#  'Edit distance': 1,
#  'Online plate matching': 1,
#  'Two-point plate survey': 1,
#  'Autoencoders': 1,
#  'Railway traffic management': 1,
#  'Sustainable travel behaviors': 1,
#  'Personalized incentives and controls': 1,
#  'Preference learning': 1,
#  'Traffic signal control systems': 1,
#  'Multi-agent systems': 1,
#  'Artificial immune network': 1,
#  'Fixed-time control': 1,
#  'Dynamic rebalancing': 1,
#  'Static rebalancing': 1,
#  'Spatial-temporal distribution learning': 1,
#  'Bike-sharing system': 1,
#  'Inventory threshold': 1,
#  'Flow-type task window': 1,
#  'Asymmetric driving behavior': 1,
#  'Short-term traffic state prediction': 1,
#  'Spatiotemporal dependencies': 1,
#  'Partial least square regression': 1,
#  'Latent structures': 1,
#  'Real-time applications': 1,
#  'Speech recognition': 1,
#  'Signal analysis': 1,
#  'Non-destructive testing': 1,
#  'Traffic signal': 1,
#  'Approximation': 1,
#  'Adaptive': 1,
#  'Travel pattern recognition': 1,
#  'Traveler attributes inference': 1,
#  'Multi-modal transportation': 1,
#  'Recommender systems': 1,
#  'Airport capacity': 1,
#  'Weather forecast': 1,
#  'Deep-learning method': 1,
#  'Multi-layer Convolutional Neural Networks': 1,
#  'Data-driven hybrid control': 1,
#  'Transit performance': 1,
#  'Traffic congestion': 1,
#  'Congestion classification': 1,
#  'Clustering analysis': 1,
#  'Image segmentation': 1,
#  'Watershed': 1,
#  'Activity-based': 1,
#  'Activity choice': 1,
#  'Short-term origin-destination prediction': 1,
#  'Channel-wise attention': 1,
#  'Split CNN': 1,
#  'Spiking neural networks': 1,
#  'Correlation adjacent matrix': 1,
#  'Multi-graph convolutional neural network': 1,
#  'Spatio-temporal feature': 1,
#  'Deep learning model': 1,
#  'Domain adaptation': 1,
#  'Traffic flow parameter': 1,
#  'Paratransit services': 1,
#  'Demand-responsive transit': 1,
#  'Stastistical modelling': 1,
#  'Deep-learning': 1,
#  'On-demand ride service': 1,
#  'Rideplitting': 1,
#  'Boosting': 1,
#  'Decision tree': 1,
#  'CNNs': 1,
#  'CE-LSTMs': 1,
#  'Residual connection': 1,
#  'Incident duration prediction': 1,
#  'Text analysis': 1,
#  'Regression models': 1,
#  'Graph wavelet': 1,
#  'Sparsity': 1,
#  'Searching for parking': 1,
#  'Smartphone sensing': 1,
#  'Cox regression': 1,
#  'Random survival forest': 1,
#  'Gipps’ model': 1,
#  'Locally weighted regression (loess)': 1,
#  'SAE level 3': 1,
#  'Conditional automation': 1,
#  'Takeover transition': 1,
#  'Human-robot interaction': 1,
#  'Arterial network': 1,
#  'Signal timing inference': 1,
#  'Queue length approximation': 1,
#  'Hybrid dynamic Bayesian network': 1,
#  'Activity pattern classification': 1,
#  'Social computing': 1,
#  'Location-based data': 1,
#  'O-D estimation': 1,
#  'Dynamic networks': 1,
#  'Risk evaluation': 1,
#  'State space model': 1,
#  'Anomaly event': 1,
#  'Road performance': 1,
#  'Feature fusion': 1,
#  'Rail transportation': 1,
#  'Condition monitoring': 1,
#  'Railway sleepers': 1,
#  'Visual inspection': 1,
#  'Restless bandits': 1,
#  'Whittle index': 1,
#  'Spherical data analysis': 1,
#  'Incremental learning': 1,
#  'Multivariate multiple regression': 1,
#  'Sliding windows': 1,
#  'Streaming data': 1,
#  'Railroad blocking and classification': 1,
#  'Algorithmic blocking': 1,
#  'Shortest path': 1,
#  'Control strategies': 1,
#  'Rail freight transportation': 1,
#  'Driver intention': 1,
#  'Intelligent vehicle': 1,
#  'String similarity': 1,
#  'Traffic state forecasting': 1,
#  'Graph convolutional neural network (GCN)': 1,
#  'Spatio-temporal dependencies': 1,
#  'Generative adversarial framework': 1,
#  'Traffic flow management': 1,
#  'Capacity management': 1,
#  'Transportation resilience': 1,
#  'Extreme weather events': 1,
#  'Urban road networks': 1,
#  'Spatiotemporal traffic prediction': 1,
#  'Graph Convolutional Neural Network': 1,
#  'Adaptive traffic signal controller': 1,
#  'Actor-critic': 1,
#  'Pedestrians': 1,
#  'Traffic disruptions': 1,
#  'Google Street View': 1,
#  'Mapillary': 1,
#  'Pedestrian': 1,
#  'Traffic safety': 1,
#  'Data-driven mobility management': 1,
#  'Attitude based segmentation techniques': 1,
#  'Crowdsourcing mobility behaviour': 1,
#  'Smartphone based mobility data collection': 1,
#  'Smart city mobility': 1,
#  'Crash analysis': 1,
#  'Accident analysis': 1,
#  'Collision risk': 1,
#  'Space-based ADS-B': 1,
#  'Segmented Kalman filter': 1,
#  'Track fitting': 1,
#  'Person re-identification': 1,
#  'Vehicle re-identification': 1,
#  'Flow monitoring': 1,
#  'Semi-supervised learning technique': 1,
#  'Probe vehicle trajectory': 1,
#  'Mixed corridor': 1,
#  'Ensemble': 1,
#  'Customer booking prediction': 1,
#  'Soft voting': 1,
#  'Railway traffic': 1,
#  'Stochastic processes': 1,
#  'Next location prediction': 1,
#  'Self-attention': 1,
#  'Short-term traffic speed forecasting': 1,
#  'Support Vector Machine': 1,
#  'Chaos': 1,
#  'Wavelet Analysis': 1,
#  'Interaction patterns': 1,
#  'Vehicle-to-vehicle (V2V)': 1,
#  'Bayesian nonparametric learning': 1,
#  'Driving primitives': 1,
#  'Graph Convolution Neural Network': 1,
#  'Data-driven graph filter': 1,
#  'Long Short-term Memory network': 1,
#  'Spatio-temporal demand prediction': 1,
#  'Freeway safety': 1,
#  'Automatic Vehicle Identification': 1,
#  'Remote Traffic Microwave Sensor': 1,
#  'Stochastic Gradient Boosting': 1,
#  'Online location-based search': 1,
#  'Logistic regression': 1,
#  'Automatic vehicle identification': 1,
#  'Taxi-out prediction': 1,
#  'Flight delay': 1,
#  'Basic safety messages': 1,
#  'Multinomial logit model': 1,
#  'Instrumented vehicle data': 1,
#  'Connected vehicle data': 1,
#  'Traffic status detection': 1,
#  'Arterial roads': 1,
#  'Cellular event': 1,
#  'Bidirectional LSTM': 1,
#  'Backward dependency': 1,
#  'Traffic conflict': 1,
#  'Safety space': 1,
#  'Object based tracking': 1,
#  'Unmanned aerial vehicle (UAV)': 1,
#  'public transit OD estimation': 1,
#  'Transfer detection': 1,
#  'Origin inference': 1,
#  'Destination inference': 1,
#  'OD scaling': 1,
#  'Adaptive Cruise Control (ACC)': 1,
#  'Learning-machine': 1,
#  'Advanced Driving Assistance Systems (ADAS)': 1,
#  'Intelligent Transportation Systems (ITS)': 1,
#  'Dynamic systems': 1,
#  'Bus arrival time prediction': 1,
#  'Multiple bus routes': 1,
#  ' nearest neighbours algorithm': 1,
#  'Gaussian graphical model': 1,
#  'Mixture model': 1,
#  'Urban flow': 1,
#  'Ordinary differential equations': 1,
#  'Spatial–temporal learning': 1,
#  'Time series prediction': 1,
#  'Generative Adversarial Networks': 1,
#  'Connectivity': 1,
#  'Cybernetics': 1,
#  'Crowd-sensing': 1,
#  'Short-term traffic predictions': 1,
#  'Measure accuracy': 1,
#  'SARMA models': 1,
#  'Variable speed limit': 1,
#  'Flight fuel burn prediction': 1,
#  'Uncertainty estimation': 1,
#  'Benefit assessment': 1,
#  'PSO-ELM': 1,
#  'Reliability': 1,
#  'Sharpness': 1,
#  'Staffing plan': 1,
#  'Waiting time': 1,
#  'Congestion maps': 1,
#  'Travel times': 1,
#  'Freeway': 1,
#  'Consensual learning': 1,
#  'Junction tree': 1,
#  'Signal control coordination': 1,
#  'VISSIM': 1,
#  'Emissions': 1,
#  'MOVES': 1,
#  'Advanced booking model': 1,
#  'Booking curve': 1,
#  'Arrival forecasting': 1,
#  'Global Positioning System (GPS)': 1,
#  'Support Vector Machine (SVM)': 1,
#  'Gradient boosting logit': 1,
#  'High-resolution traffic even data': 1,
#  'Wearable GPS data': 1,
#  'Map service API': 1,
#  'Driving cycle detection': 1,
#  'High-speed rail (HSR)': 1,
#  'Hybrid model': 1,
#  'Ensemble empirical mode decomposition (EEMD)': 1,
#  'Grey support vector machine (GSVM)': 1,
#  'Traffic demand': 1,
#  'Origin-destination matrix': 1,
#  'OD matrix estimation': 1,
#  '3D supply patterns': 1,
#  'Ride-hailing prediction': 1,
#  'Graph convolutional neural networks': 1,
#  'Sequence to sequence learning': 1,
#  'Spatio-temporal analysis': 1,
#  'Multiple modality': 1,
#  'Information search': 1,
#  'Query processing': 1,
#  'Spatio-temporal data management': 1,
#  'Driverless cars': 1,
#  'Regulation': 1,
#  'Generalized heterogenous data model': 1,
#  'Digital assistants': 1,
#  'Hubs': 1,
#  'Synchronization': 1,
#  'Blockchain': 1,
#  'Cybersecurity': 1,
#  'Big Data': 1,
#  'Long term': 1,
#  'Short term': 1,
#  'Bus bunching prediction': 1,
#  'Headway irregularity': 1,
#  'Least squares support vector machine': 1,
#  'Data Analytics': 1,
#  'Extreme Events': 1,
#  'Statistical variability': 1,
#  'Kernel Density Estimation': 1,
#  'Automatic Event Detection': 1,
#  'Complexity': 1,
#  'Future and emerging technologies': 1,
#  'Serious games': 1,
#  'Game-based model': 1,
#  'ICT': 1,
#  'Bus travel time': 1,
#  'Real-time traffic information': 1,
#  'Frequent Pattern tree (FP tree)': 1,
#  'Fuzzy C-means clustering (FCM)': 1,
#  'k Nearest Neighbor (-NN)': 1,
#  'Variable selection': 1,
#  'Real time': 1,
#  'Relative Object Purity Ratio (ROPR)': 1,
#  'Traffic accident risk prediction': 1,
#  'Truck traffic': 1,
#  'Container transport': 1,
#  'Port community system': 1,
#  'Ride-sourcing service': 1,
#  'Surge pricing': 1,
#  'VRUs protection': 1,
#  'V2P communication': 1,
#  'Autonomous vehicle Interaction': 1,
#  'Pedestrian collision avoidance': 1,
#  'Personalized Adaptive Cruise Control system': 1,
#  'Driving style': 1,
#  'Human driving data': 1,
#  'Gaussian mixture model': 1,
#  'KL divergence': 1,
#  'Aircraft performance': 1,
#  'Kinematic model': 1,
#  'Data collection': 1,
#  'Crash prediction': 1,
#  'Fixation': 1,
#  'Physiological measures': 1,
#  'Discriminant analysis': 1,
#  'Long short-term neural network': 1,
#  'Remote microwave detector data': 1,
#  'Route-choice': 1,
#  'System optimum': 1,
#  'Aircraft': 1,
#  'State estimation': 1,
#  'Observation noise': 1,
#  'Bayesian estimation': 1,
#  'Traffic flow dynamics': 1,
#  'Oscillation': 1,
#  'Electricity use': 1,
#  'Urban system interdependency': 1,
#  'Trip extraction methods': 1,
#  'DCI framework': 1,
#  'Multi-sourced data': 1,
#  'App-based data': 1,
#  'Mobility patterns': 1,
#  'Dynamic graph': 1,
#  'Surrogate models': 1,
#  'Computational intelligence': 1,
#  'Electric vehicles (EVs)': 1,
#  'Driver acceptance': 1,
#  'Commercial EV fleet': 1,
#  'Drivers’ efficiency perception': 1,
#  'Germany': 1,
#  'Technology Acceptance Model': 1,
#  'Bayesian neural network': 1,
#  'Traveler information systems': 1,
#  'ATIS': 1,
#  'Driver cognitive distraction': 1,
#  'Distraction detection': 1,
#  'Distraction mitigation': 1,
#  'Layered algorithm': 1,
#  'Supervised clustering': 1,
#  'Real-time crash risk evaluation': 1,
#  'On-line model updating': 1,
#  'Bayesian dynamic logistic regression': 1,
#  'In-field streaming traffic data': 1,
#  'Fuel consumption reduction': 1,
#  'Hybrid powertrain optimization': 1,
#  'Inter-vehicle communication': 1,
#  'Infrastructure management': 1,
#  'Public bicycle': 1,
#  'Bicycling environments': 1,
#  'Bicycle speed data': 1,
#  'Bicycle traffic monitoring': 1,
#  'Query expansion': 1,
#  'Information retrieval': 1,
#  'On–demand mobility': 1,
#  'Car–passenger assignments': 1,
#  'Immediate response': 1,
#  'Dial-a-ride problem': 1,
#  'Nearest neighbor policy': 1,
#  'List–based assignments': 1,
#  'Short-term metro passenger flow': 1,
#  'Empirical mode decomposition': 1,
#  'Surrogate model': 1,
#  'Macroscopic fundamental diagram': 1,
#  'Kernel trick': 1,
#  'Aviation': 1,
#  'Aviation safety': 1,
#  'Aviation safety reporting system': 1,
#  'Connected environment': 1,
#  'Random parameter': 1,
#  'Duration model': 1,
#  'Lane changing': 1,
#  'Intention recognition': 1,
#  'Hidden Markov models': 1,
#  'Bayesian filtering': 1,
#  'Speech recognition model': 1,
#  'Driver assistance systems': 1,
#  'Connected vehicle technology': 1,
#  'Vehicle-to-infrastructure': 1,
#  'Driver reactions': 1,
#  ...}

# %% [markdown]
# # Algorithms

# %% [markdown]
# ## Create Dictionary of Algorithms

# %%
Algorithms = {
    'ANN:  Artificial Neural Network': ['Artificial Neural Network'],
    'Bayesian': ['Bayesian Logistics Regression', 'Bayes'],
    'Binomial Regression': ['Binomial Regression'],
    'Convex Hull Algorithm': ['Convex Hull'],
    'CNN:  Convolutional Neural Network': ['Convolutional Neural Network', 'CNN'],
    'CIF: Cumulative Incidence Function': ['Cumulative Incidence Function'],
    'Decision Jungle': ['Decision Jungle'],
    'Deep Learning': ['Deep Learning', 'deep-learning'],
    'Dimensionality Reduction': ['Dimensionality Reduction'],
    'Dynamic Bayesian Network': ['Dynamic Bayesian'],
    'Ensemble': ['Ensemble'],
    'Feature Extraction': ['Feature Extraction'],
    'Fuzzy Logic': ['Fuzzy Logic'],
    'Genetic Algorithm': ['Genetic Algorithm', 'Genetic Programming'],
    'IGA: Intelligent Genetic Algorithm': ['Intelligent Genetic Algorithm'],
    'Logistic Regression': ['Logistic Regression'],
    'LSTM: Long Short-Term Memory': ['Long Short-term Memory'],
    'Marginal Effect Analysis': ['Marginal Effect Analysis'],
    'MDU: Maximum Dissimilarity Undersampling': ['maximum dissimilarity undersampling'],
    'Mixed Methods': ['Mixed Methods'],
    'Neural Network': ['Neural Network'],
    'Random Forest':['Random Forest'],
    'RSF: Random Survival Forest': ['Random Survival Forest'],
    'Shapley': ['Shapley'],
    'Statistical Learning': ['Statistical learning'],
    'SMO: Synthetic Minority Oversampling': ['synthetic minority oversampling'],
    't-SNE': ['t-SNE'],
    'VIMP: Variable Importance': ['Variable Importance'],
    'XGBoost':['XGBoost', 'XGB'],

}

# %% [markdown]
# ## Find Mentions of Algorithms in Abstracts or Keywords

# %%
for alg in Algorithms:
    P[alg] = P['abstract'].str.contains('|'.join(Algorithms[alg]), case=False) | P['keywords'].str.contains('|'.join(Algorithms[alg]), case=False)

# %% [markdown]
# ## Count Mentions of Algorithms in Abstracts or Keywords

# %%
A = P[Algorithms.keys()].sum()
A.sort_values(ascending=False)
# Out:
# Neural Network                              93
# Deep Learning                               56
# Bayesian                                    44
# Random Forest                               24
# CNN:  Convolutional Neural Network          24
# Ensemble                                    20
# LSTM: Long Short-Term Memory                18
# ANN:  Artificial Neural Network             17
# Genetic Algorithm                           10
# Logistic Regression                          8
# Feature Extraction                           7
# VIMP: Variable Importance                    3
# XGBoost                                      3
# Fuzzy Logic                                  3
# Dynamic Bayesian Network                     3
# Dimensionality Reduction                     1
# RSF: Random Survival Forest                  1
# SMO: Synthetic Minority Oversampling         1
# t-SNE                                        1
# Decision Jungle                              0
# Marginal Effect Analysis                     0
# MDU: Maximum Dissimilarity Undersampling     0
# Mixed Methods                                0
# CIF: Cumulative Incidence Function           0
# Convex Hull Algorithm                        0
# Shapley                                      0
# Statistical Learning                         0
# Binomial Regression                          0
# IGA: Intelligent Genetic Algorithm           0
# dtype: int64

# %% [markdown]
# # Analysis Tools

# %% [markdown]
# ## Create Dictionary of Analysis Tools

# %%
Analysis_Tools = {
    'Sensitivity': ['Sensitivity'],
    'Area under Curve': ['Area under Curve'],
    'False Alarm Rate': ['False Alarm Rate'],
    'Accuracy': ['accuracy'],
    'Precision': ['macro-average precision'], 
    'Recall': ['macro-average recall'], 
    'Geometric Mean': ['geometric mean'],
    'Hyperparameters': ['Hyperparameter'],
    'Spearman': ['Spearman'],
    'Aggregated Gain': ['Aggregated Gain'],
    'Time Dependencies': ['Time dependencies'],
    'Temporal': ['Temporal'],
    'Kinematic': ['Kinematic'],
    'Visualization': ['Visualization'],
    'F1 Loss Function': ['F1'],
    'Connected Vehicles': ['Connected Vehicles'],
    'Imbalanced Data': ['Imbalanced Data'],
}

# %% [markdown]
# ## Find Mentions of Analysis Tools in Abstracts or Keywords

# %%
for alg in Analysis_Tools:
    P[alg] = P['abstract'].str.contains('|'.join(Analysis_Tools[alg]), case=False) | P['keywords'].str.contains('|'.join(Analysis_Tools[alg]), case=False)

# %% [markdown]
# ## Count Mentions of Analysis Tools in Abstracts or Keywordes

# %%
A = P[Analysis_Tools.keys()].sum()
A.sort_values(ascending=False)
# Out:
# Accuracy              125
# Temporal               99
# Sensitivity            19
# Visualization           7
# Kinematic               7
# Connected Vehicles      6
# False Alarm Rate        4
# Hyperparameters         4
# F1 Loss Function        3
# Spearman                1
# Imbalanced Data         1
# Time Dependencies       0
# Aggregated Gain         0
# Area under Curve        0
# Geometric Mean          0
# Recall                  0
# Precision               0
# dtype: int64

# %% [markdown]
# # Datasets
# ## Create Dictionary of Datasets

# %%
Datasets = {
    'Second Highway Research Program (Data Set)': ['Second Highway Research Program', 'SHRP2'],
    'Virginia 100-car Database': ['Virginia', '100-car', '100 car'],
    'NGSIM Trajectory Data': ['NGSIM'],
    
}

# %% [markdown]
# ## Find Mentions of Dataset in Abstract and Keywords

# %%
for x in Datasets:
    P[x] = P['abstract'].str.contains('|'.join(Datasets[x]), case=False) | P['keywords'].str.contains('|'.join(Datasets[x]), case=False)

# %% [markdown]
# ## Count Mentions of Datasets in Abstracts and Keywords

# %%
A = P[Datasets.keys()].sum()
A.sort_values(ascending=False)
# Out:
# NGSIM Trajectory Data                         9
# Virginia 100-car Database                     5
# Second Highway Research Program (Data Set)    1
# dtype: int64

# %% [markdown]
# # Authors

# %% [markdown]
# ## Sort Authors by Frequency

# %%
P['author'] = P['author'].fillna('None')
A = [ x.split(' and ') for x in P['author'].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# {'Li Li': 9,
#  'Yinhai Wang': 8,
#  'Francisco C. Pereira': 7,
#  'Meng Li': 6,
#  'Qing He': 6,
#  'Zhengbing He': 6,
#  'Zhiyuan Liu': 6,
#  'Xuesong Zhou': 6,
#  'Satish V. Ukkusuri': 6,
#  'Haris N. Koutsopoulos': 6,
#  'Xi Lin': 5,
#  'Xuegang (Jeff) Ban': 5,
#  'Hai Yang': 5,
#  'Lijun Sun': 5,
#  'Jie Sun': 5,
#  'Wei Ma': 5,
#  'Jinhua Zhao': 5,
#  'Constantinos Antoniou': 5,
#  'Yunpeng Wang': 5,
#  'Adel W. Sadek': 5,
#  'Zhen (Sean) Qian': 5,
#  'Zuduo Zheng': 5,
#  'Jian Sun': 4,
#  'Yang Liu': 4,
#  'Jintao Ke': 4,
#  'Xiqun (Michael) Chen': 4,
#  'Bilal Farooq': 4,
#  'Cynthia Chen': 4,
#  'Mohamed Abdel-Aty': 4,
#  'Xiaolei Ma': 4,
#  'Lei Lin': 4,
#  'Fang He': 3,
#  'Zhengchao Zhang': 3,
#  'Eleni I. Vlahogianni': 3,
#  'Qiangqiang Guo': 3,
#  'Nikola Marković': 3,
#  'Jiwon Kim': 3,
#  'Xi Zhu': 3,
#  'Jun Chen': 3,
#  'R. John Hansman': 3,
#  'Lei Zhang': 3,
#  'Zheng Zhu': 3,
#  'Xiqun Chen': 3,
#  'Xidong Pi': 3,
#  'Sean Qian': 3,
#  'Lingqiao Qin': 3,
#  'Christian Eduardo {Verdonk Gallego}': 3,
#  'Bin Ran': 3,
#  'Manuel Angel {Amaro Carmona}': 3,
#  'Jieping Ye': 3,
#  'Yu Zhang': 3,
#  'Zuo Zhang': 3,
#  'Fei-Yue Wang': 3,
#  'Samiul Hasan': 3,
#  'Chen Cai': 3,
#  'Hans {van Lint}': 3,
#  'Filipe Rodrigues': 3,
#  'Moshe Ben-Akiva': 3,
#  'Zhiyong Cui': 3,
#  'Ziyuan Pu': 3,
#  'Francesco Corman': 3,
#  'Haiyang Yu': 3,
#  'Junzi Sun': 3,
#  'Joost Ellerbroek': 3,
#  'Jacco M. Hoekstra': 3,
#  'Rongjie Yu': 3,
#  'Kuilin Zhang': 3,
#  'Davy Janssens': 3,
#  'Geert Wets': 3,
#  'Ludovic Leclercq': 3,
#  'Ke Zhang': 2,
#  'Jing Gao': 2,
#  'Xuan Di': 2,
#  'Xiaohui Zhang': 2,
#  'Daniel B. Work': 2,
#  'Bin Jia': 2,
#  'Yuan Wang': 2,
#  'Ohay Angah': 2,
#  'Pan Liu': 2,
#  'Sina Dabiri': 2,
#  'Kevin Heaslip': 2,
#  'Hwasoo Yeo': 2,
#  'James Haworth': 2,
#  'Tao Cheng': 2,
#  'Lili Du': 2,
#  'Fangce Guo': 2,
#  'Rajesh Krishnan': 2,
#  'Mayara Condé Rocha Murça': 2,
#  'Lishuai Li': 2,
#  'Zhibin Jiang': 2,
#  'Jinjing Gu': 2,
#  'Mohammed Quddus': 2,
#  'Wen-Hua Chen': 2,
#  'Asad J. Khattak': 2,
#  'Jingshuo Feng': 2,
#  'Shuai Huang': 2,
#  'Rahul Nair': 2,
#  'Yuchuan Du': 2,
#  'Víctor Fernando {Gómez Comendador}': 2,
#  'Francisco Javier {Sáez Nieto}': 2,
#  'Rosa María {Arnaldo Valdés}': 2,
#  'Melvin Wong': 2,
#  'Yuankai Wu': 2,
#  'Huachun Tan': 2,
#  'Shenhao Wang': 2,
#  'Wei Liu': 2,
#  'Yanru Zhang': 2,
#  'Ali Haghani': 2,
#  'Reza Mohammadi': 2,
#  'Faeze Ghofrani': 2,
#  'Zhiguo Li': 2,
#  'Feng Xiao': 2,
#  'Liping Fu': 2,
#  'Jiawei Wang': 2,
#  'Zhaocheng He': 2,
#  'Alexander E.I. Brownlee': 2,
#  'John R. Woodward': 2,
#  'Michal Weiszer': 2,
#  'Qing Cai': 2,
#  'Jinghui Yuan': 2,
#  'Qiang Meng': 2,
#  'Qixiu Cheng': 2,
#  'Xinwu Qian': 2,
#  'Kenneth D. Kuhn': 2,
#  'Yanbo Pang': 2,
#  'Takehiro Kashiyama': 2,
#  'Yoshihide Sekimoto': 2,
#  'Mehdi Ghatee': 2,
#  'Bo Yu': 2,
#  'Shan Bao': 2,
#  'Alexei Pozdnoukhov': 2,
#  'Kunpeng Zhang': 2,
#  'Choudhury Siddique': 2,
#  'Hai L. Vu': 2,
#  'Xianyuan Zhan': 2,
#  'Ruimin Li': 2,
#  'Feilong Wang': 2,
#  'Jingxing Wang': 2,
#  'Siril Yella': 2,
#  'Narendra K. Gupta': 2,
#  'Bin Yu': 2,
#  'Panchamy Krishnakumari': 2,
#  'Feng Chen': 2,
#  'Ibai Laña': 2,
#  'Javier {Del Ser}': 2,
#  'Zhengfei Zheng': 2,
#  'Zhigang Xu': 2,
#  'Ruimin Ke': 2,
#  'Dawn M. Tilbury': 2,
#  'Lionel P. Robert': 2,
#  'X. Jessie Yang': 2,
#  'Mark Dougherty': 2,
#  'Mahmoud Mesbah': 2,
#  'Yuan Meng': 2,
#  'Stanislav S. Borysov': 2,
#  'Jeppe Rich': 2,
#  'Yuming Ou': 2,
#  'Wenshuo Wang': 2,
#  'Ashish Bhaskar': 2,
#  'Gennaro Nicola Bifulco': 2,
#  'Luigi Pariota': 2,
#  'William H.K. Lam': 2,
#  'Gaetano Fusco': 2,
#  'Yiming Gu': 2,
#  'Lei Zhu': 2,
#  'Nicolas Chiabaut': 2,
#  'Guizhen Yu': 2,
#  'Oded Cats': 2,
#  'Bo Xu': 2,
#  'Enrique Onieva': 2,
#  'Yunlong Zhang': 2,
#  'Ido Klein': 2,
#  'Eran Ben-Elia': 2,
#  'Qian Wang': 2,
#  'Yuande Jiang': 2,
#  'Weiwen Deng': 2,
#  'Rui Jiang': 2,
#  'Xiaobo Qu': 2,
#  'Xiaopeng Li': 2,
#  'Yu Cui': 2,
#  'Xuesong Wang': 2,
#  'Jianfeng Zheng': 2,
#  'Henry X. Liu': 2,
#  'Ke Han': 2,
#  'Md. Mazharul Haque': 2,
#  'Nicolas Saunier': 2,
#  'Zhan Zhao': 2,
#  'Shuofeng Wang': 2,
#  'Wanjing Ma': 2,
#  'Wei Wang': 2,
#  'Guohui Zhang': 2,
#  'Peter J. Jin': 2,
#  'Xinyu Chen': 2,
#  'Silvio Nocera': 2,
#  'Francisco {Saez Nieto}': 2,
#  'Luis F. Miranda-Moreno': 2,
#  'Asad Khattak': 2,
#  'Ziyou Gao': 2,
#  'Nina Schefers': 2,
#  'Juan José {Ramos González}': 2,
#  'Pau Folch': 2,
#  'José Luis Munoz-Gamarra': 2,
#  'Joseph Y.J. Chow': 2,
#  'Luk Knapen': 2,
#  'R.X. Zhong': 2,
#  'A. Sumalee': 2,
#  'Ziyuan Gu': 2,
#  'Meead Saberi': 2,
#  'Shan Huang': 2,
#  'Natasha Merat': 2,
#  'Stephen G. Ritchie': 2,
#  'Avishai (Avi) Ceder': 2,
#  'Jian Wang': 2,
#  'S.P. Hoogendoorn': 2,
#  'Venktesh Pandey': 2,
#  'Stephen D. Boyles': 2,
#  'Andrea Simonetto': 2,
#  'Julien Monteil': 2,
#  'Claudio Gambella': 2,
#  'Mecit Cetin': 2,
#  'Monica Menendez': 2,
#  'Yang Li': 2,
#  'Jiaqi Ma': 2,
#  'Mohamed H. Zaki': 2,
#  'Tarek Sayed': 2,
#  'Erik Jenelius': 2,
#  'Emmanouil N. Barmpounakis': 1,
#  'Zhenhua Zhang': 1,
#  'Ming Ni': 1,
#  'Zhenyu Shou': 1,
#  'Siyu Hao': 1,
#  'Der-Horng Lee': 1,
#  'De Zhao': 1,
#  'Jan Drchal': 1,
#  'Michal Čertický': 1,
#  'Michal Jakob': 1,
#  'Yingjun Ye': 1,
#  'William Barbour': 1,
#  'Juan Carlos {Martinez Mori}': 1,
#  'Shankara Kuppa': 1,
#  'Dong-Fan Xie': 1,
#  'Zhe-Zhe Fang': 1,
#  'Pramuditha Suraweera': 1,
#  'Geoffrey I. Webb': 1,
#  'Ian Evans': 1,
#  'Mark Wallace': 1,
#  'Mohamed Salama': 1,
#  'Sharan Srinivas': 1,
#  'Dongxiang Zhang': 1,
#  'Ying Liu': 1,
#  'Bo Dai': 1,
#  'Loo Hay Lee': 1,
#  'Ruo Jia': 1,
#  'Zhijun Liu': 1,
#  'Zouhair {Elamrani Abou Elassad}': 1,
#  'Hajar Mousannif': 1,
#  'Hassan {Al Moatassime}': 1,
#  'Xinglei Wang': 1,
#  'Xuefeng Guan': 1,
#  'Jun Cao': 1,
#  'Na Zhang': 1,
#  'Huayi Wu': 1,
#  'Chengcheng Xu': 1,
#  'Junyi Ji': 1,
#  'Nicholas G. Polson': 1,
#  'Vadim O. Sokolov': 1,
#  'Hongyu Zheng': 1,
#  'Raj Deshmukh': 1,
#  'Dawei Sun': 1,
#  'Kwangyeon Kim': 1,
#  'Inseok Hwang': 1,
#  'Guoyi Li': 1,
#  'Hyunseong Lee': 1,
#  'Ashwin Rai': 1,
#  'Aditi Chattopadhyay': 1,
#  'Sanjin Milinković': 1,
#  'Konstantin S. Tikhonov': 1,
#  'Paul Schonfeld': 1,
#  'Lijuan Liu': 1,
#  'Rung-Ching Chen': 1,
#  'Arash Kalatian': 1,
#  'Tianyi Chen': 1,
#  'Xiupeng Shi': 1,
#  'Yiik Diew Wong': 1,
#  'Xiaocong Yu': 1,
#  'Seongjin Choi': 1,
#  'Linsen Chong': 1,
#  'Montasir M. Abbas': 1,
#  'Alejandra {Medina Flintsch}': 1,
#  'Bryan Higgs': 1,
#  'R. Alligier': 1,
#  'D. Gianazza': 1,
#  'N. Durand': 1,
#  'Qing Hou': 1,
#  'Chengbo Ai': 1,
#  'Xianbin Cao': 1,
#  'Zhencai Tian': 1,
#  'Dapeng Wu': 1,
#  'Wenbo Du': 1,
#  'Luis Delgado': 1,
#  'Gérald Gurtner': 1,
#  'Tatjana Bolić': 1,
#  'Lorenzo Castelli': 1,
#  'Zhao Yang': 1,
#  'Rong Tang': 1,
#  'Weili Zeng': 1,
#  'Jiahuan Lu': 1,
#  'Zhijie Zhang': 1,
#  'John Shawe-Taylor': 1,
#  'Jiaqiu Wang': 1,
#  'Hanyi Yang': 1,
#  'Jamshid Mohammadi': 1,
#  'Junyi Li': 1,
#  'Aruna Sivakumar': 1,
#  'Yanjie Dong': 1,
#  'Pan Ren': 1,
#  'Yanshuo Sun': 1,
#  'Min Zhou': 1,
#  'Yeming Li': 1,
#  'Dewei Yi': 1,
#  'Jinya Su': 1,
#  'Cunjia Liu': 1,
#  'Zaharah {Allah Bukhsh}': 1,
#  'Aaqib Saeed': 1,
#  'Irina Stipanovic': 1,
#  'Andre G. Doree': 1,
#  'Xiao Qi': 1,
#  'Amin Mohammadnazar': 1,
#  'Ramin Arvin': 1,
#  'Shuguan Yang': 1,
#  'Thanh Lam Hoang': 1,
#  'Marco Laumanns': 1,
#  'Bei Chen': 1,
#  'Randall Cogill': 1,
#  'Jácint Szabó': 1,
#  'Thomas Walter': 1,
#  'Yuanli Gu': 1,
#  'Wenqi Lu': 1,
#  'Zhuangzhuang Shao': 1,
#  'Chenglong Liu': 1,
#  'Difei Wu': 1,
#  'Yishun Li': 1,
#  'Taehooie Kim': 1,
#  'Shivam Sharda': 1,
#  'Ram M. Pendyala': 1,
#  'Guillermo {Orenga Imaz}': 1,
#  'Mohammad Hesam Hafezi': 1,
#  'Naznin Sultana Daisy': 1,
#  'Hugh Millward': 1,
#  'Lei Liu': 1,
#  'Wenwen Zhang': 1,
#  'Kaidi Wang': 1,
#  'Sicheng Wang': 1,
#  'Zhiqiu Jiang': 1,
#  'Andrew Mondschein': 1,
#  'Robert B. Noland': 1,
#  'Michael Schultz': 1,
#  'Stefan Reitmann': 1,
#  'Zhuxi Jiang': 1,
#  'Qingyi Wang': 1,
#  'Wei Fan': 1,
#  'Bingqin Zhu': 1,
#  'Chandan K. Reddy': 1,
#  'Xiao Han': 1,
#  'Guojiang Shen': 1,
#  'Xi Yang': 1,
#  'Xiangjie Kong': 1,
#  'Zhengyi Wang': 1,
#  'Man Liang': 1,
#  'Daniel Delahaye': 1,
#  'Abhishek Pathak': 1,
#  'Amjad Aref': 1,
#  'Miguel {García Martínez}': 1,
#  'Hongfei Li': 1,
#  'Dhaivat Parikh': 1,
#  'Buyue Qian': 1,
#  'Dongping Fang': 1,
#  'Arun Hampapur': 1,
#  'Wenwen Tu': 1,
#  'Lu Li': 1,
#  'Qijun Chen': 1,
#  'Yuxi Xie': 1,
#  'Yu Ao': 1,
#  'Tiange Li': 1,
#  'Guorong Chen': 1,
#  'Shaofei Ren': 1,
#  'Chao Wang': 1,
#  'Shaofan Li': 1,
#  'Ruixiang Chen': 1,
#  'Sudatta Mohanty': 1,
#  'Alexey Pozdnukhov': 1,
#  'Michael Cassidy': 1,
#  'Richard Alligier': 1,
#  'David Gianazza': 1,
#  'Sebastián Hughes': 1,
#  'Sebastián Moreno': 1,
#  'Wilfredo F. Yushimito': 1,
#  'Gonzalo Huerta-Cánepa': 1,
#  'Xinwei Wang': 1,
#  'Mahdi Mahfouf': 1,
#  'Tong Wang': 1,
#  'Jiahua Cao': 1,
#  'Azhar Hussain': 1,
#  'Lijing Ma': 1,
#  'Shiru Qu': 1,
#  'Rui Yao': 1,
#  'Shlomo Bekhor': 1,
#  'Tejas G. Puranik': 1,
#  'Nicolas Rodriguez': 1,
#  'Dimitri N. Mavris': 1,
#  'Ahmed Lasisi': 1,
#  'Nii Attoh-Okine': 1,
#  'Nada Mahmoud': 1,
#  'James J.Q. Yu': 1,
#  'Przemysław Sekuła': 1,
#  'Zachary {Vander Laan}': 1,
#  'Kaveh Farokhi Sadabadi': 1,
#  'Rongye Shi': 1,
#  'Zengxiang Lei': 1,
#  'Matteo Simoncini': 1,
#  'Leonardo Taccari': 1,
#  'Francesco Sambo': 1,
#  'Luca Bravi': 1,
#  'Samuele Salti': 1,
#  'Alessandro Lori': 1,
#  'Eleftheria Kontou': 1,
#  'Venu Garikapati': 1,
#  'Yi Hou': 1,
#  'Dongwei Xu': 1,
#  'Chenchen Wei': 1,
#  'Peng Peng': 1,
#  'Qi Xuan': 1,
#  'Haifeng Guo': 1,
#  'Mehmet Baran Ulak': 1,
#  'Anil Yazici': 1,
#  'Yun Zhang': 1,
#  'Takahiro Yabe': 1,
#  'Kota Tsubouchi': 1,
#  'Mohammad Mahdi Bejani': 1,
#  'Tao Ma': 1,
#  'Tomer Toledo': 1,
#  'Valentino Servizi': 1,
#  'Niklas C. Petersen': 1,
#  'Otto A. Nielsen': 1,
#  'Anton Dekusar': 1,
#  'Junlin Yao': 1,
#  'Ayman Moawad': 1,
#  'Siyuan Feng': 1,
#  'Wei-Hsun Lee': 1,
#  'Li-Hsien Yen': 1,
#  'Chien-Ming Chou': 1,
#  'Marko Hrastovec': 1,
#  'Franc Solina': 1,
#  'Qi Cao': 1,
#  'Gang Ren': 1,
#  'Dawei Li': 1,
#  'Jiangshan Ma': 1,
#  'Haojie Li': 1,
#  'John Sullivan': 1,
#  'Mike Flannagan': 1,
#  'Trisalyn Nelson': 1,
#  'Avipsa Roy': 1,
#  'Colin Ferster': 1,
#  'Jaimy Fischer': 1,
#  'Vanessa Brum-Bastos': 1,
#  'Karen Laberee': 1,
#  'Hanchen Yu': 1,
#  'Meghan Winters': 1,
#  'Danya Bachir': 1,
#  'Ghazaleh Khodabandelou': 1,
#  'Vincent Gauthier': 1,
#  'Mounim {El Yacoubi}': 1,
#  'Jakob Puchinger': 1,
#  'Sid Feygin': 1,
#  'Anca Apatean': 1,
#  'Alexandrina Rogozan': 1,
#  'Abdelaziz Bensrhair': 1,
#  'Ning Jia': 1,
#  'Liang Zheng': 1,
#  'Zijian Liu': 1,
#  'Xingyuan Dai': 1,
#  'Rui Fu': 1,
#  'Enmin Zhao': 1,
#  'Yilun Lin': 1,
#  'Jaeyoung Lee': 1,
#  'Yina Wu': 1,
#  'Loan N.N. Do': 1,
#  'Bao Q. Vo': 1,
#  'Dinh Phung': 1,
#  'Md Mehedi Hasnat': 1,
#  'Jinsoo You': 1,
#  'Tschangho John Kim': 1,
#  'Rui Hou': 1,
#  'Seongwoon Jeong': 1,
#  'Jerome P. Lynch': 1,
#  'Kincho H. Law': 1,
#  'Francisco Moraes Oliveira-Neto': 1,
#  'Lee D. Han': 1,
#  'Myong K. Jeong': 1,
#  'Xavier Olive': 1,
#  'Luis Basora': 1,
#  'Taha Ghasempour': 1,
#  'Benjamin Heydecker': 1,
#  'Derek D. Reed': 1,
#  'Saber Darmoul': 1,
#  'Sabeur Elkosantini': 1,
#  'Ali Louati': 1,
#  'Lamjed {Ben Said}': 1,
#  'Zihao Tian': 1,
#  'Jing Zhou': 1,
#  'W.Y. Szeto': 1,
#  'Lixin Tian': 1,
#  'Wenbin Zhang': 1,
#  'Xiuling Huang': 1,
#  'Wan Li': 1,
#  'Rong Fan': 1,
#  'Yiran Zhang': 1,
#  'Mark S. Dougherty': 1,
#  'Chi Kwong Wong': 1,
#  'Benjamin G. Heydecker': 1,
#  'Can Li': 1,
#  'Lei Bai': 1,
#  'Lina Yao': 1,
#  'S. {Travis Waller}': 1,
#  'Cheng Lyu': 1,
#  'Jinde Cao': 1,
#  'Wensi Wang': 1,
#  'Jiaming Liu': 1,
#  'Baozhen Yao': 1,
#  'Yonglei Jiang': 1,
#  'Tin T. Nguyen': 1,
#  'Simeon C. Calvert': 1,
#  'Johan W. Joubert': 1,
#  'Alta {de Waal}': 1,
#  'Jinlei Zhang': 1,
#  'Hongshu Che': 1,
#  'Jesus L. Lobo': 1,
#  'Elisa Capecci': 1,
#  'Nikola Kasabov': 1,
#  'Xiaoran Qin': 1,
#  'Jinlong Li': 1,
#  'Lan Fu': 1,
#  'Hongkai Yu': 1,
#  'Ektoras Chandakas': 1,
#  'Fang Yuan': 1,
#  'Ruey Long Cheu': 1,
#  'Majid Zahiri': 1,
#  'Shuaichao Zhang': 1,
#  'Ge Guo': 1,
#  'Tianqi Zhang': 1,
#  'Eleni G. Mantouka': 1,
#  'Panagiotis Fafoutellis': 1,
#  'Vasileia Papathanasopoulou': 1,
#  'Na Du': 1,
#  'Feng Zhou': 1,
#  'Elizabeth M. Pulver': 1,
#  'Anuj K. Pradhan': 1,
#  'Ignacio (Iñaki) Olabarrieta': 1,
#  'Manuel Vélez': 1,
#  'Shogo Umeda': 1,
#  'Yosuke. Kawasaki': 1,
#  'Masao. Kuwahara': 1,
#  'Akira Iihoshi': 1,
#  'Pedro Cesar {Lopes Gerum}': 1,
#  'Ayca Altay': 1,
#  'Melike Baykal-Gürsoy': 1,
#  'Arnab Kumar Laha': 1,
#  'Sayan Putatunda': 1,
#  'Erick D. Wikum': 1,
#  'Yang Xing': 1,
#  'Chen Lv': 1,
#  'Huaji Wang': 1,
#  'Dongpu Cao': 1,
#  'Efstathios Velenis': 1,
#  'Hamed Faroqi': 1,
#  'Byeonghyeop Yu': 1,
#  'Yongjin Lee': 1,
#  'Keemin Sohn': 1,
#  'Hong-Wei Wang': 1,
#  'Zhong-Ren Peng': 1,
#  'Dongsheng Wang': 1,
#  'Tianlong Wu': 1,
#  'Weili Sun': 1,
#  'Qing-Chang Lu': 1,
#  'Mohammad Aslani': 1,
#  'Mohammad Saadi Mesgari': 1,
#  'Marco Wiering': 1,
#  'C. Bustos': 1,
#  'D. Rhoads': 1,
#  'A. Solé-Ribalta': 1,
#  'D. Masip': 1,
#  'A. Arenas': 1,
#  'A. Lapedriza': 1,
#  'J. Borge-Holthoefer': 1,
#  'Ivana Semanjski': 1,
#  'Sidharta Gautama': 1,
#  'Andreas Gregoriades': 1,
#  'Kyriacos C. Mouskos': 1,
#  'Fei Lu': 1,
#  'Zichen Chen': 1,
#  'Huiyu Chen': 1,
#  'George Adaimi': 1,
#  'Sven Kreiss': 1,
#  'Alexandre Alahi': 1,
#  'Yu Mei': 1,
#  'Keshuang Tang': 1,
#  'Keping Li': 1,
#  'Le-Minh Kieu': 1,
#  'Long T. Truong': 1,
#  'Pavle Kecman': 1,
#  'Jin Wang': 1,
#  'Qixin Shi': 1,
#  'Weiyang Zhang': 1,
#  'Srinivas Peeta': 1,
#  'Mohamed Ahmed': 1,
#  'Alireza Ermagun': 1,
#  'Yingling Fan': 1,
#  'Julian Wolfson': 1,
#  'Gediminas Adomavicius': 1,
#  'Kirti Das': 1,
#  'Franco Basso': 1,
#  'Leonardo J. Basso': 1,
#  'Francisco Bravo': 1,
#  'Raul Pezoa': 1,
#  'Poornima Balakrishna': 1,
#  'Rajesh Ganesan': 1,
#  'Lance Sherry': 1,
#  'Mohsen Kamrani': 1,
#  'Aravinda Ramakrishnan Srinivasan': 1,
#  'Subhadeep Chakraborty': 1,
#  'Shen Li': 1,
#  'Guofa Li': 1,
#  'Yang Cheng': 1,
#  'Albert Y. Chen': 1,
#  'Yen-Lin Chiu': 1,
#  'Meng-Hsiu Hsieh': 1,
#  'Po-Wei Lin': 1,
#  'Etikaf Hussain': 1,
#  'Edward Chung': 1,
#  'Fulvio Simonelli': 1,
#  'Roberta {Di Pace}': 1,
#  'Mei Lam Tam': 1,
#  'Yusuke Hara': 1,
#  'Junpei Suzuki': 1,
#  'Masao Kuwahara': 1,
#  'Fan Zhou': 1,
#  'Liang Li': 1,
#  'Goce Trajcevski': 1,
#  'Sergio Garrido': 1,
#  'Stratis Kanarachos': 1,
#  'Stavros-Richard G. Christopoulos': 1,
#  'Alexander Chroneos': 1,
#  'Chiara Colombaroni': 1,
#  'Natalia Isaenko': 1,
#  'Lei Kang': 1,
#  'Mark Hansen': 1,
#  'John C. Handley': 1,
#  'Xuejin Wen': 1,
#  'Rémi Faitout': 1,
#  'Feng Zhu': 1,
#  'H.M. Abdul Aziz': 1,
#  'Tsung-Hsien Tsai': 1,
#  'Zhanbo Sun': 1,
#  'Chuan Ding': 1,
#  'Xinkai Wu': 1,
#  'Jeffrey D. Gonder': 1,
#  'Xiushan Jiang': 1,
#  'Xiqun {(Michael) Chen}': 1,
#  'Tamara Djukic': 1,
#  'Guangyin Jin': 1,
#  'Yan Cui': 1,
#  'Liang Zeng': 1,
#  'Hanbo Tang': 1,
#  'Yanghe Feng': 1,
#  'Jincai Huang': 1,
#  'Ouri Wolfson': 1,
#  'A. Prasad Sistla': 1,
#  'Gopindra S. Nair': 1,
#  'Chandra R. Bhat': 1,
#  'Menno Yap': 1,
#  'Ding Luo': 1,
#  'Niels {van Oort}': 1,
#  'Serge Hoogendoorn': 1,
#  'David López': 1,
#  'Toon Bogaerts': 1,
#  'Antonio D. Masegosa': 1,
#  'Juan S. Angarita-Zapata': 1,
#  'Peter Hellinckx': 1,
#  'Dongwei Chen': 1,
#  'Zhihai Wu': 1,
#  'Kieran Kalair': 1,
#  'Colm Connaughton': 1,
#  'Jiaman Ma': 1,
#  'Jeffrey Chan': 1,
#  'Goce Ristanoski': 1,
#  'Sutharshan Rajasegarar': 1,
#  'Christopher Leckie': 1,
#  'Ali Nadi': 1,
#  'Salil Sharma': 1,
#  'Maaike Snelder': 1,
#  'Taoufik Bakri': 1,
#  'Lóránt Tavasszy': 1,
#  'Matthew Battifarano': 1,
#  'Sara {El Hamdani}': 1,
#  'Nabil Benamar': 1,
#  'Mohamed Younis': 1,
#  'Bing Zhu': 1,
#  'Jian Zhao': 1,
#  'Rui He': 1,
#  'Ning Bian': 1,
#  'Yutao Ba': 1,
#  'Wei Zhang': 1,
#  'Qinhua Wang': 1,
#  'Ronggang Zhou': 1,
#  'Changrui Ren': 1,
#  'Zhimin Tao': 1,
#  'Nadav Levy': 1,
#  'Henk A.P. Blom': 1,
#  'Mofan Zhou': 1,
#  'Pinchao Zhang': 1,
#  'Jinzhou Cao': 1,
#  'Dapeng Zhang': 1,
#  'Minyu Shen': 1,
#  'Shaopeng Zhong': 1,
#  'Stefanie Wolff': 1,
#  'Reinhard Madlener': 1,
#  'Chuishi Meng': 1,
#  'Jeffrey L Adler': 1,
#  'Victor J Blue': 1,
#  'Yulan Liang': 1,
#  'John D. Lee': 1,
#  'Kui Yang': 1,
#  'Mohd Azrin {Mohd Zulkefli}': 1,
#  'Zongxuan Sun': 1,
#  'Aditya Medury': 1,
#  'Samer Madanat': 1,
#  'Shinhye Joo': 1,
#  'Cheol Oh': 1,
#  'Eunbi Jeong': 1,
#  'Gunwoo Lee': 1,
#  'Ioulia Markou': 1,
#  'Kevin Kaiser': 1,
#  'Marvin Erdmann': 1,
#  'Florian Dandl': 1,
#  'Klaus Bogenberger': 1,
#  'Yu Wei': 1,
#  'Mu-Chen Chen': 1,
#  'Qian Ge': 1,
#  'Daisuke Fukuda': 1,
#  'Wenjing Song': 1,
#  'Yasir Ali': 1,
#  'Michiel C.J. Bliemer': 1,
#  'Keqiang Li': 1,
#  'Xiao Wang': 1,
#  'Youchun Xu': 1,
#  'Jianqiang Wang': 1,
#  'Fred Feng': 1,
#  'James Sayer': 1,
#  'Shuaidong Zhao': 1,
#  'Shuaian Wang': 1,
#  'Yu Yuan': 1,
#  'Ping Huang': 1,
#  'Javad Lessan': 1,
#  'Chao Wen': 1,
#  'Qiyuan Peng': 1,
#  'Xinyue Xu': 1,
#  'Xuegang {(Jeff) Ban}': 1,
#  'Darcy Bullock': 1,
#  'James Garrett': 1,
#  'Chris Hendrickson': 1,
#  'Haiyang Wang': 1,
#  'Longyuan Li': 1,
#  'Pingjun Pan': 1,
#  'Yongkun Wang': 1,
#  'Yaohui Jin': 1,
#  'Oscar Oviedo-Trespalacios': 1,
#  'Mark King': 1,
#  'Simon Washington': 1,
#  'Mingqiao Zou': 1,
#  'Chenfeng Xiong': 1,
#  'Chao Mao': 1,
#  'Cheng Wan': 1,
#  'Jiaying Yu': 1,
#  'Paul St-Aubin': 1,
#  'Luis Miranda-Moreno': 1,
#  'Alessio D. Marra': 1,
#  'Henrik Becker': 1,
#  'Kay W. Axhausen': 1,
#  'Baichuan Mo': 1,
#  'Chengkai Zhang': 1,
#  'Junchi Bin': 1,
#  'Wells Wang': 1,
#  'Xiang Peng': 1,
#  'Rui Wang': 1,
#  'Richard Halldearn': 1,
#  'Zheng Liu': 1,
#  'John W. Polak': 1,
#  'Peter Bonsall': 1,
#  'Ian Palmer': 1,
#  'Jessica {Van Brummelen}': 1,
#  'Marie O’Brien': 1,
#  'Dominique Gruyer': 1,
#  'Homayoun Najjaran': 1,
#  'Adel Bolbol': 1,
#  'Ioannis Tsapakis': 1,
#  'Jingru Yu': 1,
#  'Marc E.J. Stettler': 1,
#  'Panagiotis Angeloudis': 1,
#  'Simon Hu': 1,
#  'Yin Zheng': 1,
#  'Guangnian Xiao': 1,
#  'Zhicai Juan': 1,
#  'Chunqin Zhang': 1,
#  'Runkun Liu': 1,
#  'Hamid Reza Eftekhari': 1,
#  'Dongyao Jia': 1,
#  'Anshuman Sharma': 1,
#  'Bingyi Liu': 1,
#  'Longfei Lin': 1,
#  'Shuyan Chen': 1,
#  'Gaofeng Qu': 1,
#  'Xin Wu': 1,
#  'Jifu Guo': 1,
#  'Kai Xian': 1,
#  'Peyman Noursalehi': 1,
#  'George Yannis': 1,
#  'Sander {van Cranenburgh}': 1,
#  'Ahmad Alwosheel': 1,
#  'Yichuan Peng': 1,
#  'Qi Shi': 1,
#  'B. Anil Kumar': 1,
#  'Lelitha Vanajakshi': 1,
#  'Shankar C. Subramanian': 1,
#  'Cong Chen': 1,
#  'Hua Wang': 1,
#  'Jinfu Yang': 1,
#  'C. {Michael Walton}': 1,
#  'Johan Barthélemy': 1,
#  'Timoteo Carletti': 1,
#  'Jinming Yang': 1,
#  'M.N. Sharath': 1,
#  'Nagendra R. Velaga': 1,
#  'Mostafa H. Tawfeek': 1,
#  'Karim El-Basyouny': 1,
#  'Ahmad {Haj Mosa}': 1,
#  'Kyandoghere Kyamakya': 1,
#  'Ralf Junghans': 1,
#  'Mouhannad Ali': 1,
#  'Fadi {Al Machot}': 1,
#  'Markus Gutmann': 1,
#  'Heikki Mäenpää': 1,
#  'Andrei Lobov': 1,
#  'Jose L. {Martinez Lastra}': 1,
#  'Cayetano Ruiz-Alarcón-Quintero': 1,
#  'Federico Cavallaro': 1,
#  'Fuwen Deng': 1,
#  'Feixiong Liao': 1,
#  'A. Tympakianaki': 1,
#  'A. Spiliopoulou': 1,
#  'A. Kouvelas': 1,
#  'I. Papamichail': 1,
#  'M. Papageorgiou': 1,
#  'Y. Wang': 1,
#  'Yalda Rajabzadeh': 1,
#  'Amir Hossein Rezaie': 1,
#  'Hamidreza Amindavar': 1,
#  'Huiping Li': 1,
#  'Farman Ali': 1,
#  'Daehan Kwak': 1,
#  'Pervez Khan': 1,
#  'S.M. Riazul Islam': 1,
#  'Kye Hyun Kim': 1,
#  'K.S. Kwak': 1,
#  'Weiran Yao': 1,
#  'Mehdi {Rafati Fard}': 1,
#  'Afshin {Shariat Mohaymany}': 1,
#  'Haosheng Huang': 1,
#  'Yi Cheng': 1,
#  'Robert Weibel': 1,
#  'Rob M.P. Goverde': 1,
#  'Xiang Liu': 1,
#  'Daniele Gammelli': 1,
#  'Inon Peled': 1,
#  'Dario Pacino': 1,
#  'Haci A. Kurtaran': 1,
#  'Antony D. Evans': 1,
#  'Paul Lee': 1,
#  'Banavar Sridhar': 1,
#  'Sohail Zangenehpour': 1,
#  'Rui Sun': 1,
#  'Jun Hu': 1,
#  'Yanjun Wang': 1,
#  'Minghua Hu': 1,
#  'Washington Yotto Ochieng': 1,
#  'Joseph L. Schofer': 1,
#  'Frank S. Koppelman': 1,
#  'Sameer Alam': 1,
#  'Kamran Shafi': 1,
#  'Hussein A. Abbass': 1,
#  'Michael Barlow': 1,
#  'Jiateng Yin': 1,
#  'Tao Tang': 1,
#  'Lixing Yang': 1,
#  'Jing Xun': 1,
#  'Yeran Huang': 1,
#  'Su Yang': 1,
#  'Barry Sheehan': 1,
#  'Finbarr Murphy': 1,
#  'Cian Ryan': 1,
#  'Martin Mullins': 1,
#  'Hai Yue Liu': 1,
#  'Aritra Pal': 1,
#  'Yajie Zou': 1,
#  'Xin Ye': 1,
#  'Kristian Henrickson': 1,
#  'Jinjun Tang': 1,
#  'Siddhartha Sharma': 1,
#  'Zhongwei Sun': 1,
#  'Theo Arentze': 1,
#  'Harry Timmermans': 1,
#  'Amna Bouhana': 1,
#  'Afef Fekih': 1,
#  'Mourad Abed': 1,
#  'Habib Chabchoub': 1,
#  'Chenyi Chen': 1,
#  'Yin Wang': 1,
#  'Jianming Hu': 1,
#  'Mohamed Ghazel': 1,
#  'Shun Yang': 1,
#  'Jian Wu': 1,
#  'Sumin Zhang': 1,
#  'Brian Yueshuai He': 1,
#  'Le Minh Kieu': 1,
#  'Franco {van Wyk}': 1,
#  'Anahita Khojandi': 1,
#  'Neda Masoud': 1,
#  'Zhihao Zhang': 1,
#  'Peng Chen': 1,
#  'Xiao Zhang': 1,
#  'Asier Perallos': 1,
#  'Eneko Osaba': 1,
#  'Victor C.S. Lee': 1,
#  'Stéphane Galland': 1,
#  'Ansar-Ul-Haque Yasar': 1,
#  'Nicolas Gaud': 1,
#  'Olivier Lamotte': 1,
#  'Abderrafiaa Koukam': 1,
#  'Tianya Zhang': 1,
#  'Christian Will': 1,
#  'Alexander Schuller': 1,
#  'Qinzheng Wang': 1,
#  'Yun Yuan': 1,
#  'Xianfeng (Terry) Yang': 1,
#  'Zhitong Huang': 1,
#  'J.C. Luo': 1,
#  'H.X. Cai': 1,
#  'F.F. Yuan': 1,
#  'Andy H.F. Chow': 1,
#  'Ali Ghasemzadeh': 1,
#  'Mohamed M. Ahmed': 1,
#  'Tyron Louw': 1,
#  'Tom Bellemans': 1,
#  'Muhammad Usman': 1,
#  'Yongqi Dong': 1,
#  'Thanos Bantis': 1,
#  'Carina Fors': 1,
#  'Katja Kircher': 1,
#  'Christer Ahlström': 1,
#  'O. Burkhard': 1,
#  'H. Becker': 1,
#  'R. Weibel': 1,
#  'K.W. Axhausen': 1,
#  'Isaac {Martín de Diego}': 1,
#  'Oscar {S. Siordia}': 1,
#  'Raúl Crespo': 1,
#  'Cristina Conde': 1,
#  'Enrique Cabello': 1,
#  'Junchuan Fan': 1,
#  'Cheng Fu': 1,
#  'Kathleen Stewart': 1,
#  'Baher Abdulhai': 1,
#  'Azim Shariff': 1,
#  'Jean-François Bonnefon': 1,
#  'Iyad Rahwan': 1,
#  'Francois Belletti': 1,
#  'Alexandre M. Bayen': 1,
#  'Ralf Schleiffer': 1,
#  'Zhichao Cao': 1,
#  'Silin Zhang': 1,
#  'Junxuan Zhao': 1,
#  'Hao Xu': 1,
#  'Hongchao Liu': 1,
#  'Jianqing Wu': 1,
#  'Yichen Zheng': 1,
#  'Dayong Wu': 1,
#  'Wei Deng': 1,
#  'Yuntao Guo': 1,
#  'J.W.C. {van Lint}': 1,
#  'H.J. {van Zuylen}': 1,
#  'Unsok Ryu': 1,
#  ...}

# %% [markdown]
# ## Who are these Authors?

# %% [markdown]
# ### Mohamed Abdel-Aty
# - U of Central Florida
# - Editor in Chief Emeritus of the journal
# - PhD from Davis
#
# ### Zhibin Li
# - Southeast University, Nanjing
#
# ### Junhua Wang
# - Tongji U, Shanghai
#
# ### Rongjie Yu
# - Coauthor with Mohamed Abdel-Aty
# - Tongji U, Shanghai
#
# ### Pan Liu
# - Southeast University, Nanjing
# - Coauthors:
#     - Jie Bao (2)
#     - Satish V. Ukkusuri
#     - Xiao Qin
#     - Huaguo Zhou
#     - Yanyong Guo
#     - Zhibin Li (2)
#     - Yao Wu
#     - Wei Wang (2)
#     - Chengcheng Xu (2)
#
# ### Asad J. Khattak
# - U of Tennessee

# %% [markdown]
# # Institutions
# ## Sort Institutions by Frequency

# %%
x = 'institution'
P[x] = P[x].fillna('None')
A = [ x.split(', ') for x in P[x].tolist() ]
B = [item for sublist in A for item in sublist]
C = {x:B.count(x) for x in B}
D = dict(sorted(C.items(), key=lambda item: item[1], reverse=True))
D
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'institution'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-33764f48dc88> in <module>
#       1 x = 'institution'
# ----> 2 P[x] = P[x].fillna('None')
#       3 A = [ x.split(', ') for x in P[x].tolist() ]
#       4 B = [item for sublist in A for item in sublist]
#       5 C = {x:B.count(x) for x in B}
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'institution'

# %% [markdown]
# # Interesting Articles

# %%
P['annotation'] = P['annotation'].fillna('None')
Interesting = P[P['annotation'].str.contains('Interesting', case=False)]
Interesting

# %% [markdown]
# # Not Machine Learning

# %%
A = P[P['annotation'].str.contains('Not ML', case=False)]
A
